# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
import pandas as pd

# %%
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x=tips["total_bill"])

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips)

# %%
dates = pd.date_range('20130101',periods=6)
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.509070  0.447637 -1.384233  0.976836
# 2013-01-02 -1.639944 -0.006898 -2.875309 -1.055444
# 2013-01-03  1.456291 -0.248152  2.620473  2.627957
# 2013-01-04  0.199206  1.000675 -0.277924 -1.482003
# 2013-01-05  0.887885 -0.408584 -0.332723 -2.097379
# 2013-01-06 -0.704337 -0.112268 -1.538902  0.147780

# %%
my_columns = list(["msg", "seq", "stamp", "latency"])
df2 = pd.DataFrame(columns=my_columns)
df3 = pd.DataFrame(list([["Pose", 2, 3434.537, 6.789]]), columns=my_columns)
df4 = pd.DataFrame(list([["Pose", 3, 5434.537, 7.789]]), columns=my_columns)

print df3
print df4

df5 = df3.append(df4, ignore_index=True)

print df5
# Out:
#     msg  seq     stamp  latency
# 0  Pose    2  3434.537    6.789
#     msg  seq     stamp  latency
# 0  Pose    3  5434.537    7.789
#     msg  seq     stamp  latency
# 0  Pose    2  3434.537    6.789
# 1  Pose    3  5434.537    7.789

# %%
latency_columns = list(["msg", "seq", "stamp", "latency"])
latency_df = pd.DataFrame(columns=latency_columns)
with open('/home/peteflo/latency/sim_latency_7.txt') as f:
    lines = f.readlines()
    for line in lines:
        words = line.split()
        words[1] = int(words[1])
        words[2] = float(words[2])
        words[3] = float(words[3])
        latency_df_add = pd.DataFrame([words], columns=latency_columns)
        latency_df = latency_df.append(latency_df_add, ignore_index=True)

# %%
ax = sns.violinplot(x="msg", y="latency", data=latency_df)

# %%
with open('/home/peteflo/latency/sim_latency_7.txt') as f:
    lines = f.readlines()
    for line in lines:
        for word in line.split():
            print word
        print " "
# Out:
# POSE
# 74944
# 1488465693.411572979
# 0.004691876
#
# TWIST
# 74944
# 1488465693.411581691
# 0.005288613
#
# POSE
# 74945
# 1488465693.421772730
# 0.001444624
#
# TWIST
# 74945
# 1488465693.421778705
# 0.001953082
#
# POSE
# 74946
# 1488465693.431594394
# 0.001601104
#
# TWIST
# 74946
# 1488465693.431601896
# 0.001995128
#
# POSE
# 74947
# 1488465693.441568537
# 0.001601921
#
# TWIST
# 74947
# 1488465693.441574942
# 0.002023583
#
# POSE
# 74948
# 1488465693.451508470
# 0.002171829
#
# TWIST
# 74948
# 1488465693.451515090
# 0.002608243
#
# POSE
# 74949
# 1488465693.461514237
# 0.001711902
#
# TWIST
# 74949
# 1488465693.461520470
# 0.002118466
#
# POSE
# 74950
# 1488465693.471749694
# 0.001415813
#
# TWIST
# 74950
# 1488465693.471756184
# 0.001836114
#
# POSE
# 74951
# 1488465693.481535706
# 0.001667336
#
# TWIST
# 74951
# 1488465693.481543811
# 0.002315135
#
# POSE
# 74952
# 1488465693.491496598
# 0.002187941
#
# TWIST
# 74952
# 1488465693.491506201
# 0.002613492
#
# POSE
# 74953
# ...
